# %%
import rasa 
import nest_asyncio
nest_asyncio.apply()
print("Event loop ready.")
config = "config.yml"
training_files = "data/"
domain = "domain.yml"
output = "models/"
# Out:
# Event loop ready.

# %%
model_path = rasa.train(domain, config, [training_files], output)
# Out:
# Epochs: 100%|██████████| 100/100 [00:42<00:00,  2.37it/s, t_loss=1.5, i_acc=0.99]
# Processed story blocks: 100%|██████████| 61/61 [00:00<00:00, 861.46it/s, # trackers=1]
# Processed story blocks: 100%|██████████| 61/61 [00:00<00:00, 89.68it/s, # trackers=50]
# Processed story blocks: 100%|██████████| 61/61 [00:00<00:00, 62.86it/s, # trackers=50]
# Processed story blocks: 100%|██████████| 61/61 [00:00<00:00, 102.20it/s, # trackers=50]
# Processed trackers: 100%|██████████| 58/58 [00:00<00:00, 1140.31it/s, # action=117]
# Processed actions: 117it [00:00, 1029.07it/s, # examples=117]
# Processed trackers: 0it [00:00, ?it/s]
# Processed trackers: 100%|██████████| 58/58 [00:00<00:00, 908.66it/s, # action=117]
# Processed trackers: 0it [00:00, ?it/s]
# Processed trackers: 100%|██████████| 58/58 [00:00<00:00, 3634.69it/s]
# Processed trackers: 100%|██████████| 558/558 [00:00<00:00, 582.20it/s, # action=1223]
# Epochs: 100%|██████████| 200/200 [23:20<00:00,  7.00s/it, t_loss=0.77, loss=0.248, acc=0.996]
# Your Rasa model is trained and saved at 'models\20220121-000757-foggy-cube.tar.gz'.

# %%
from rasa.utils.endpoints import EndpointConfig
from rasa.core.agent import Agent
import asyncio
modelPath=r"C:\Users\luhar\Projects\Covid19-Chatbot\models\20220121-000757-foggy-cube.tar.gz"
agent = Agent.load(str(modelPath))

# %%
from typing import Text
async def parse(text: Text):
    global agent
    response = await agent.handle_text(text)
    return response
while(True):
    userMsg=input("")
    if agent.is_ready():
        loop = asyncio.new_event_loop()
        asyncio.set_event_loop(loop)
        response = loop.run_until_complete(parse(userMsg))

    if response is not None :
        if type(response) is list:
            print(response[0].get('text'))
        else:
            print(response)
    else:
        print('The response was not valid')
# Out:
# Sorry I am unable to understand your question or your question is not related to Covid-19 Information.
# Yes, Covid vaccines are  Availbale.Please go through the mentioned link for the details of vaccines approved by WHO.https://covid19.trackvaccines.org/agency/who/
# Hello..Say What do you want to know.
# Please folow the mentioned link to get latest updates on Hospital bed availability
# If there is curfew in your city, please dont go outside. Otherwise you can go out maintaining social distance by wearing mask.
# Sorry I am unable to understand your question or your question is not related to Covid-19 Information.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10084/4191899377.py in <module>
#       9         loop = asyncio.new_event_loop()
#      10         asyncio.set_event_loop(loop)
# ---> 11         response = loop.run_until_complete(parse(userMsg))
#      12
#      13     if response is not None :
#
# ~\anaconda3\lib\site-packages\nest_asyncio.py in run_until_complete(self, future)
#      62                 f._log_destroy_pending = False
#      63             while not f.done():
# ---> 64                 self._run_once()
#      65                 if self._stopping:
#      66                     break
#
# ~\anaconda3\lib\site-packages\nest_asyncio.py in _run_once(self)
#      98             handle = ready.popleft()
#      99             if not handle._cancelled:
# --> 100                 handle._run()
#     101         handle = None
#     102
#
# ~\anaconda3\lib\asyncio\events.py in _run(self)
#      79     def _run(self):
#      80         try:
# ---> 81             self._context.run(self._callback, *self._args)
#      82         except (SystemExit, KeyboardInterrupt):
#      83             raise
#
# ~\anaconda3\lib\site-packages\nest_asyncio.py in step(task, exc)
#     167         curr_task = curr_tasks.get(task._loop)
#     168         try:
# --> 169             step_orig(task, exc)
#     170         finally:
#     171             if curr_task is None:
#
# ~\anaconda3\lib\asyncio\tasks.py in __step(***failed resolving arguments***)
#     278                 # We use the `send` method directly, because coroutines
#     279                 # don't have `__iter__` and `__next__` methods.
# --> 280                 result = coro.send(None)
#     281             else:
#     282                 result = coro.throw(exc)
#
# ~\AppData\Local\Temp/ipykernel_10084/4191899377.py in parse(text)
#       2 async def parse(text: Text):
#       3     global agent
# ----> 4     response = await agent.handle_text(text)
#       5     return response
#       6 while(True):
#
# ~\anaconda3\lib\site-packages\rasa\core\agent.py in handle_text(self, text_message, output_channel, sender_id)
#     512         msg = UserMessage(text_message.get("text"), output_channel, sender_id)
#     513
# --> 514         return await self.handle_message(msg)
#     515
#     516     def _set_fingerprint(self, fingerprint: Optional[Text] = None) -> None:
#
# ~\anaconda3\lib\site-packages\rasa\core\agent.py in handle_message(self, message)
#     428
#     429         async with self.lock_store.lock(message.sender_id):
# --> 430             return await self.processor.handle_message(message)
#     431
#     432     @agent_must_be_ready
#
# ~\anaconda3\lib\site-packages\rasa\core\processor.py in handle_message(self, message)
#     134         """Handle a single message with this processor."""
#     135         # preprocess message if necessary
# --> 136         tracker = await self.log_message(message, should_save_tracker=False)
#     137
#     138         if self.model_metadata.training_type == TrainingType.NLU:
#
# ~\anaconda3\lib\site-packages\rasa\core\processor.py in log_message(self, message, should_save_tracker)
#     381         )
#     382
# --> 383         await self._handle_message_with_tracker(message, tracker)
#     384
#     385         if should_save_tracker:
#
# ~\anaconda3\lib\site-packages\rasa\core\processor.py in _handle_message_with_tracker(self, message, tracker)
#     680             parse_data = message.parse_data
#     681         else:
# --> 682             parse_data = await self.parse_message(message)
#     683
#     684         # don't ever directly mutate the tracker
#
# ~\anaconda3\lib\site-packages\rasa\core\processor.py in parse_message(self, message, only_output_properties)
#     633             parse_data = await self.http_interpreter.parse(message)
#     634         else:
# --> 635             parse_data = self._parse_message_with_graph(message, only_output_properties)
#     636
#     637         logger.debug(
#
# ~\anaconda3\lib\site-packages\rasa\core\processor.py in _parse_message_with_graph(self, message, only_output_properties)
#     657             Parsed data extracted from the message.
#     658         """
# --> 659         results = self.graph_runner.run(
#     660             inputs={PLACEHOLDER_MESSAGE: [message]},
#     661             targets=[self.model_metadata.nlu_target],
#
# ~\anaconda3\lib\site-packages\rasa\engine\runner\dask.py in run(self, inputs, targets)
#     104
#     105         try:
# --> 106             dask_result = dask.get(run_graph, run_targets)
#     107             return dict(dask_result)
#     108         except RuntimeError as e:
#
# ~\anaconda3\lib\site-packages\dask\local.py in get_sync(dsk, keys, **kwargs)
#     551     """
#     552     kwargs.pop("num_workers", None)  # if num_workers present, remove it
# --> 553     return get_async(
#     554         synchronous_executor.submit,
#     555         synchronous_executor._max_workers,
#
# ~\anaconda3\lib\site-packages\dask\local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     494             while state["waiting"] or state["ready"] or state["running"]:
#     495                 fire_tasks(chunksize)
# --> 496                 for key, res_info, failed in queue_get(queue).result():
#     497                     if failed:
#     498                         exc, tb = loads(res_info)
#
# ~\anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# ~\anaconda3\lib\concurrent\futures\_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# ~\anaconda3\lib\site-packages\dask\local.py in submit(self, fn, *args, **kwargs)
#     536         fut = Future()
#     537         try:
# --> 538             fut.set_result(fn(*args, **kwargs))
#     539         except BaseException as e:
#     540             fut.set_exception(e)
#
# ~\anaconda3\lib\site-packages\dask\local.py in batch_execute_tasks(it)
#     232     Batch computing of multiple tasks with `execute_task`
#     233     """
# --> 234     return [execute_task(*a) for a in it]
#     235
#     236
#
# ~\anaconda3\lib\site-packages\dask\local.py in <listcomp>(.0)
#     232     Batch computing of multiple tasks with `execute_task`
#     233     """
# --> 234     return [execute_task(*a) for a in it]
#     235
#     236
#
# ~\anaconda3\lib\site-packages\dask\local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     223         failed = False
#     224     except BaseException as e:
# --> 225         result = pack_exception(e, dumps)
#     226         failed = True
#     227     return key, result, failed
#
# ~\anaconda3\lib\site-packages\dask\local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     218     try:
#     219         task, data = loads(task_info)
# --> 220         result = _execute_task(task, data)
#     221         id = get_id()
#     222         result = dumps((result, id))
#
# ~\anaconda3\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     117         # temporaries by their reference count and can execute certain
#     118         # operations in-place.
# --> 119         return func(*(_execute_task(a, cache) for a in args))
#     120     elif not ishashable(arg):
#     121         return arg
#
# ~\anaconda3\lib\site-packages\rasa\engine\graph.py in __call__(self, *inputs_from_previous_nodes)
#     459
#     460         try:
# --> 461             output = self._fn(self._component, **run_kwargs)
#     462         except InvalidConfigException:
#     463             # Pass through somewhat expected exception to allow more fine granular
#
# ~\anaconda3\lib\site-packages\rasa\nlu\classifiers\diet_classifier.py in process(self, messages)
#    1001         """Augments the message with intents, entities, and diagnostic data."""
#    1002         for message in messages:
# -> 1003             out = self._predict(message)
#    1004
#    1005             if self.component_config[INTENT_CLASSIFICATION]:
#
# ~\anaconda3\lib\site-packages\rasa\nlu\classifiers\diet_classifier.py in _predict(self, message)
#     930         # create session data from message and convert it into a batch of 1
#     931         model_data = self._create_model_data([message], training=False)
# --> 932         return self.model.run_inference(model_data)
#     933
#     934     def _predict_label(
#
# ~\anaconda3\lib\site-packages\rasa\utils\tensorflow\models.py in run_inference(self, model_data, batch_size, output_keys_expected)
#     313                 # We only need input, since output is always None and not
#     314                 # consumed by our TF graphs.
# --> 315                 batch_in = next(data_iterator)[0]
#     316                 batch_out: Dict[
#     317                     Text, Union[np.ndarray, Dict[Text, Any]]
#
# ~\anaconda3\lib\site-packages\keras\utils\data_utils.py in __iter__(self)
#     481   def __iter__(self):
#     482     """Create a generator that iterate over the Sequence."""
# --> 483     for item in (self[i] for i in range(len(self))):
#     484       yield item
#     485
#
# ~\anaconda3\lib\site-packages\keras\utils\data_utils.py in <genexpr>(.0)
#     481   def __iter__(self):
#     482     """Create a generator that iterate over the Sequence."""
# --> 483     for item in (self[i] for i in range(len(self))):
#     484       yield item
#     485
#
# ~\anaconda3\lib\site-packages\rasa\utils\tensorflow\data_generator.py in __getitem__(self, index)
#     396         # return input and target data, as our target data is inside the input
#     397         # data return None for the target data
# --> 398         return self.prepare_batch(self._data, start, end), None
#     399
#     400     def on_epoch_end(self) -> None:
#
# ~\anaconda3\lib\site-packages\rasa\utils\tensorflow\data_generator.py in prepare_batch(data, start, end, tuple_sizes)
#     115                     if _data.is_sparse:
#     116                         batch_data.extend(
# --> 117                             RasaDataGenerator._scipy_matrix_to_values(_data)
#     118                         )
#     119                     else:
#
# ~\anaconda3\lib\site-packages\rasa\utils\tensorflow\data_generator.py in _scipy_matrix_to_values(array_of_sparse)
#     237             indices.astype(np.int64),
#     238             data.astype(np.float32),
# --> 239             shape.astype(np.int64),
#     240         ]
#     241
#
# KeyboardInterrupt:
